# %% [markdown]
# # import packages

# %%
import numpy as np
import pandas as pd
import glob,os
from matplotlib import pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import StandardScaler,MinMaxScaler
import random
#use to make all features into one sentence
from sklearn.model_selection import train_test_split
#For resampling
from imblearn.under_sampling import TomekLinks
from imblearn.over_sampling import RandomOverSampler,ADASYN,SMOTE
from imblearn.combine import SMOTEENN,SMOTETomek
from collections import Counter

from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.ensemble import GradientBoostingClassifier,RandomForestClassifier

# %%
from sklearn.metrics import confusion_matrix

# %%
colab=1 # set it top 0 if you need jupyter

if colab:
  from google.colab import drive
  drive.mount('/content/drive',force_remount=True)
  working_dir='/content/drive/My Drive/ponzi/'
  results_dir = '/content/drive/My Drive/ponzi/'
  os.chdir(working_dir)
# Out:
# Mounted at /content/drive

# %% [markdown]
# # functions

# %%
minmaxscaler = MinMaxScaler(feature_range=(0, 1))
standardscaler = StandardScaler()

# %%
def get_traintest(df,labelname):
  df = df.replace([np.inf, -np.inf], np.nan).dropna(axis=0)
  train, test = train_test_split(df, test_size = 0.2)
  train_x = train.drop([labelname],axis=1)
  train_y = train[labelname]
  test_x = test.drop([labelname],axis=1)
  test_y = test[labelname]
  train_x = standardscaler.fit_transform(train_x)
  test_x = standardscaler.fit_transform(test_x)
  return train_x,train_y,test_x,test_y,train,test

# %%
def RF(train_x,train_y,test_x,test_y):
  #param_grid = { 'n_estimators': [15,20],'max_depth' : [15,20],}
  RF_CV = GradientBoostingClassifier( )
  #RF_CV = GridSearchCV(estimator=RandomForestClassifier(), param_grid=param_grid, cv= 5,scoring="f1")
  RF_CV.fit(train_x, train_y)
  #print("Best parameters: ",RF_CV.best_params_)
  history = RF_CV.fit(train_x, train_y)
  y_pred = RF_CV.predict(test_x) 
  test_y = np.array(test_y)
  print(classification_report(test_y, y_pred))
  ans = compute_measure_multiclass(test_y, y_pred)
  print(ans)
  return y_pred,ans

# %%
def doResamapling(data, label, method='RandomOverSampler'):
    if method=='SMOTE':
        resampling_obj=SMOTE(random_state=42)
    elif method=='RandomOverSampler':
        resampling_obj=RandomOverSampler(random_state=42)
    elif method=='SMOTEENN':
        resampling_obj=SMOTEENN(random_state=42)
    elif method=='ADASYN':
        resampling_obj=ADASYN(random_state=42)
    elif method=='TomekLinks':
    #resampling_obj=TomekLinks(random_state=42, sampling_strategy='auto')
        resampling_obj=TomekLinks(sampling_strategy='auto')
    else:
        resampling_obj=SMOTETomek(random_state=42)

    data_res, label_res=resampling_obj=resampling_obj.fit_resample(data, label)
    return data_res, label_res

# %%
def get_newtraintest(train,test):
  train_x = train.drop([labelname],axis=1)
  train_y = train[labelname]
  test_x = test.drop([labelname],axis=1)
  test_y = test[labelname]
  train_x = standardscaler.fit_transform(train_x)
  train_x = minmaxscaler.fit_transform(train_x)
  test_x = standardscaler.fit_transform(test_x)
  test_x = minmaxscaler.fit_transform(test_x)
  return train_x,train_y,test_x,test_y

# %%
d = []

# %%
metrics = ['Accuracy','sensitivity','specificity','positive prediction ratio','negative prediction ratio','F1 score','d-index']

# %% [markdown]
# # data

# %%
data = pd.read_csv('Ponzi.csv')
data.head()
# Out:
#    Unnamed: 0                             address   lifetime  most active  \
# 0           1  114Ap9G5nu78vESC648amPwSeqUorPtV5L   28329132          202
# 1           3  1168Hc7aRi1azJPFRbCMGFvS1Q7R4taiZ3    1952932           67
# 2           4  121iUY1czgXaQcEFrKKjbzMUdCquTQgPHL   17622640           71
# 3           5  121jfy7iR2Q6HCNL3oZFDK2WTjigFZRAVb  103352586           26
# 4           6  121x1rbwtPk4jg48V42zv1CprdY5Lm1ozb    3172652           14
#
#    active day  in vs out  num out  num in  num addr received  num addr sent  \
# 0        1035   1.004892     1022    1027               3430           3127
# 1          14   0.126126        7       7                 14            111
# 2         165   1.000000       86      86               1625            360
# 3         348   1.000000      208     208                752            672
# 4          82   1.000000       53      53                201            148
#
#    median delay    mean delay  minimum delay  maximum delay  \
# 0          4369   27397.61315            -64        2881479
# 1          4559  150225.53850            473        1031864
# 2         25496  107455.12200              0         989807
# 3           362  297846.06920           -427      102562674
# 4             0   39168.54321           -839        2754080
#
#    total received BTC  total sent BTC  avg received BTC  avg sent BTC  \
# 0            9.737518        9.746409          0.009528      0.009490
# 1            0.084129        0.084129          0.012018      0.012018
# 2           76.400340       76.400340          0.888376      0.888376
# 3           44.303918       44.303918          0.213000      0.213000
# 4           12.938357       12.938357          0.244120      0.244120
#
#    48 diff  class
# 0     -200      1
# 1      -65      1
# 2      -69      1
# 3       22      1
# 4       12      1

# %%
data = data.drop(['Unnamed: 0','address'],axis=1)
print('NA:',data.isnull().sum().max())
data.describe()
# Out:
# NA: 0
#            lifetime  most active    active day    in vs out       num out  \
# count  6.819000e+03  6819.000000   6819.000000  6819.000000   6819.000000
# mean   2.694412e+07   193.174512    187.487315     3.586249    158.757002
# std    5.254176e+07   385.418165   1753.027220    18.562206   1573.447201
# min    0.000000e+00     2.000000      2.000000     0.000828      0.000000
# 25%    6.229265e+05    16.000000      4.000000     0.412544      2.000000
# 50%    5.737272e+06    81.000000     27.000000     1.000000     17.000000
# 75%    2.629540e+07   177.000000     76.000000     1.142857     51.000000
# max    3.343655e+08  4856.000000  82800.000000   709.237881  63150.000000
#
#              num in  num addr received  num addr sent  median delay  \
# count   6819.000000       6.819000e+03   6.819000e+03  6.819000e+03
# mean     151.812876       2.923279e+03   3.444426e+03  8.182274e+05
# std     1518.284236       3.350098e+04   3.430694e+04  4.078997e+06
# min        0.000000       2.000000e+00   2.000000e+00 -9.000000e+00
# 25%        2.000000       1.600000e+01   2.200000e+01  1.083350e+04
# 50%       19.000000       9.800000e+01   1.240000e+02  4.669800e+04
# 75%       54.000000       3.610000e+02   1.153000e+03  1.367935e+05
# max    74719.000000       1.767354e+06   1.998305e+06  1.109263e+08
#
#          mean delay  minimum delay  maximum delay  total received BTC  \
# count  6.819000e+03   6.819000e+03   6.819000e+03         6819.000000
# mean   1.347796e+06   5.727570e+05   1.271390e+07          753.319665
# std    4.278853e+06   4.392918e+06   3.058855e+07        11860.103898
# min    0.000000e+00  -1.596362e+08   0.000000e+00            0.000000
# 25%    4.867371e+04   0.000000e+00   2.782045e+05            0.073466
# 50%    1.774707e+05   3.260000e+02   1.491815e+06            0.985315
# 75%    7.216448e+05   7.485000e+03   9.410970e+06           28.927453
# max    1.109263e+08   1.109263e+08   3.023198e+08       623015.144500
#
#        total sent BTC  avg received BTC  avg sent BTC       48 diff  \
# count     6819.000000       6819.000000   6819.000000   6819.000000
# mean       696.568270          7.030351      6.822009    -39.519871
# std      10263.775252        103.872685    101.717595   1242.214401
# min          0.000000          0.000000      0.000000 -50055.000000
# 25%          0.078521          0.015000      0.015344    -96.000000
# 50%          1.049264          0.081420      0.083709      0.000000
# 75%         31.110504          0.796665      0.812092     26.000000
# max     559547.264200       4356.869814   4356.869814  78643.000000
#
#              class
# count  6819.000000
# mean      1.075964
# std       0.975999
# min       0.000000
# 25%       0.000000
# 50%       2.000000
# 75%       2.000000
# max       2.000000

# %%
labelname = 'class'

# %%
train_x,train_y,test_x,test_y,train,test = get_traintest(data,labelname)

# %%
train_entropy = computeDataEntropy(train_x)
print('train_entropy',train_entropy)
test_entropy = computeDataEntropy(test_x)
print('test_entropy',test_entropy)
# Out:
# train_entropy 12.615328559413213
# test_entropy 11.395523290531015

# %%
method=['RandomOverSampler', 'SMOTE', 'SMOTEENN', 'SMOTETomek','TomekLinks']
train_set = []
for e in method:
  train_label = train[labelname]
  train0 = train.drop([labelname],axis=1)
  print(e)
  print('-------------------------------------')
  data_res, label_res=doResamapling(train0, train_label, e)
  t=Counter(label_res)
  major_ratio=t[0]/(t[0]+t[1])
  print('The majority type ratio {:.2f}%'.format(major_ratio*100))
  print(t[0], t[1])
  entropy=computeDataEntropy(data_res)
  print('The train data entropy after'+e+ '{:3.4f}'.format(entropy))
  res_df = pd.DataFrame(data = data_res, columns=train0.columns)
  res_df[labelname]=label_res  
  train_set.append(res_df)
# Out:
# RandomOverSampler
# -------------------------------------
# The majority type ratio 50.00%
# 2825 2825
# The train data entropy afterRandomOverSampler38.0050
# SMOTE
# -------------------------------------
# The majority type ratio 50.00%
# 2825 2825
# The train data entropy afterSMOTE37.9654
# SMOTEENN
# -------------------------------------
# The majority type ratio 37.68%
# 989 1636
# The train data entropy afterSMOTEENN37.5581
# SMOTETomek
# -------------------------------------
# The majority type ratio 47.95%
# 2355 2556
# The train data entropy afterSMOTETomek37.9117
# TomekLinks
# -------------------------------------
# The majority type ratio 89.61%
# 1966 228
# The train data entropy afterTomekLinks37.5434

# %%
yhat,ans = RF(train_x,train_y,test_x,test_y)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.55      0.57      0.56       606
#            1       0.44      0.14      0.21        57
#            2       0.60      0.61      0.61       701
#
#     accuracy                           0.57      1364
#    macro avg       0.53      0.44      0.46      1364
# weighted avg       0.57      0.57      0.57      1364
#
# diagnostic index: 1.3185832035739093
# F1 score : 0.4594389340317631
# Sensitivity: 0.4409478638381144
# Specificity: 0.7283289652197458
# Precision: 0.5308200151911695
# Negative predictive value: 0.7299408632948768
# [0.5740469208211144, 1.3185832035739093, 0.4409478638381144, 0.7283289652197458, 0.5308200151911695, 0.7299408632948768, 0.4594389340317631]

# %%
(0.46839546+0.14492754+0.82890855)/3
# Out:
# 0.4807438499999999

# %%
result_RF = []
result_RF.append(ans)
np.save('_result_ponzi',np.array(ans))
results_df = pd.DataFrame(data=ans, index=metrics, columns=['metric'])

# %% [markdown]
# resampling

# %%
for i in range(len(method)):
  print(method[i])
  print('-----------------------------------------------')
  train_set[i] = train_set[i].replace([np.inf, -np.inf], np.nan).dropna(axis=0)
  train_x,train_y,test_x,test_y = get_newtraintest(train_set[i],test)
  yhat,ans = RF(train_x,train_y,test_x,test_y)
  d.append(ans[6])
  #result_cnn.append(ansnew)
  np.save('result_RF_ponzi_'+ method[i],np.array(ans))
  print('-----------------------------------------------')
# Out:
# RandomOverSampler
# -----------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.91      0.21      0.34       606
#            1       0.67      0.07      0.13        57
#            2       0.56      0.98      0.72       701
#
#     accuracy                           0.60      1364
#    macro avg       0.71      0.42      0.39      1364
# weighted avg       0.72      0.60      0.52      1364
#
# diagnostic index: 1.3313395402719708
# F1 score : 0.3934731268234531
# Sensitivity: 0.41977588779224795
# Specificity: 0.7267417901838917
# Precision: 0.7144556633607729
# Negative predictive value: 0.8283476312740549
# [0.5997067448680352, 1.3313395402719708, 0.41977588779224795, 0.7267417901838917, 0.7144556633607729, 0.8283476312740549, 0.3934731268234531]
# -----------------------------------------------
# SMOTE
# -----------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.90      0.19      0.31       606
#            1       0.83      0.09      0.16        57
#            2       0.56      0.98      0.71       701
#
#     accuracy                           0.59      1364
#    macro avg       0.76      0.42      0.40      1364
# weighted avg       0.72      0.59      0.51      1364
#
# diagnostic index: 1.3245959441025394
# F1 score : 0.3955790920726992
# Sensitivity: 0.4205988021281293
# Specificity: 0.7225349517571665
# Precision: 0.7642488143631437
# Negative predictive value: 0.8274565505069228
# [0.593841642228739, 1.3245959441025394, 0.4205988021281293, 0.7225349517571665, 0.7642488143631437, 0.8274565505069228, 0.3955790920726992]
# -----------------------------------------------
# SMOTEENN
# -----------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.97      0.13      0.23       606
#            1       1.00      0.02      0.03        57
#            2       0.55      1.00      0.71       701
#
#     accuracy                           0.57      1364
#    macro avg       0.84      0.38      0.32      1364
# weighted avg       0.76      0.57      0.47      1364
#
# diagnostic index: 1.278094891814345
# F1 score : 0.32251105590814105
# Sensitivity: 0.3816100658042379
# Specificity: 0.7060083758826581
# Precision: 0.8401987529228371
# Negative predictive value: 0.8451178425526441
# [0.5711143695014663, 1.278094891814345, 0.3816100658042379, 0.7060083758826581, 0.8401987529228371, 0.8451178425526441, 0.32251105590814105]
# -----------------------------------------------
# SMOTETomek
# -----------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.82      0.24      0.37       606
#            1       1.00      0.04      0.07        57
#            2       0.57      0.96      0.71       701
#
#     accuracy                           0.60      1364
#    macro avg       0.80      0.41      0.38      1364
# weighted avg       0.70      0.60      0.54      1364
#
# diagnostic index: 1.3305855679816052
# F1 score : 0.3848003348164388
# Sensitivity: 0.4120229576828094
# Specificity: 0.7289518472973385
# Precision: 0.7975970821712078
# Negative predictive value: 0.805220678420644
# [0.6019061583577713, 1.3305855679816052, 0.4120229576828094, 0.7289518472973385, 0.7975970821712078, 0.805220678420644, 0.3848003348164388]
# -----------------------------------------------
# TomekLinks
# -----------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.90      0.17      0.29       606
#            1       0.50      0.11      0.17        57
#            2       0.56      0.98      0.71       701
#
#     accuracy                           0.58      1364
#    macro avg       0.65      0.42      0.39      1364
# weighted avg       0.71      0.58      0.50      1364
#
# diagnostic index: 1.3127379518119453
# F1 score : 0.389889433685541
# Sensitivity: 0.4188950729294718
# Specificity: 0.7171116222446936
# Precision: 0.6530812761575452
# Negative predictive value: 0.8189011677780909
# [0.5843108504398827, 1.3127379518119453, 0.4188950729294718, 0.7171116222446936, 0.6530812761575452, 0.8189011677780909, 0.389889433685541]
# -----------------------------------------------
